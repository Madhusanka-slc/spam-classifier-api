# %%
# !pip install cryptography
# Out:
# Requirement already satisfied: cryptography in d:\projects\1_month_coding_challenge\3_ml_api_end_point\venv\lib\site-packages (46.0.4)
# Requirement already satisfied: cffi>=2.0.0 in d:\projects\1_month_coding_challenge\3_ml_api_end_point\venv\lib\site-packages (from cryptography) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.13.2 in d:\projects\1_month_coding_challenge\3_ml_api_end_point\venv\lib\site-packages (from cryptography) (4.15.0)
# Requirement already satisfied: pycparser in d:\projects\1_month_coding_challenge\3_ml_api_end_point\venv\lib\site-packages (from cffi>=2.0.0->cryptography) (3.0)

# %%
from cryptography.fernet import Fernet

# %%
key = Fernet.generate_key().decode("utf-8")

# %%
key
# Out:
# 'rzNelAoDI5dDu_EuYXq-Iha2OyOztJv5dcqffwEbJV8='

# %%
import pathlib

# %%
BASE_DIR = pathlib.Path().resolve().parent
BASE_DIR.exists()
# Out:
# True

# %%
APP_DIR = BASE_DIR / "app"
APP_DIR.exists()
# Out:
# True

# %%
IGNORED_DIR = APP_DIR / "ignored"
SECURE_DIR = APP_DIR / "encrypted"
DECRYPTED_DIR = APP_DIR / "decrypted"
SECURE_DIR.mkdir(exist_ok=True, parents=True)
DECRYPTED_DIR.mkdir(exist_ok=True, parents=True)

# %%
fer = Fernet(key) # f"{}:"

# %%
for path in IGNORED_DIR.glob("*"):
    __path_bytes = path.read_bytes()
    data = fer.encrypt(__path_bytes)
    rel_path = path.relative_to(IGNORED_DIR)
    dest_path = SECURE_DIR / rel_path
    dest_path.write_bytes(data)

# %%
for path in SECURE_DIR.glob("*"):
    __path_bytes = path.read_bytes()
    data = fer.decrypt(__path_bytes)
    rel_path = path.relative_to(SECURE_DIR)
    dest_path = DECRYPTED_DIR / rel_path
    dest_path.write_bytes(data)
